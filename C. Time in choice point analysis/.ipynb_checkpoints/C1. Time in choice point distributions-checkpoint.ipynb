# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import wilcoxon
from scipy.stats import mannwhitneyu
# %matplotlib inline
# %run "C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\data_prep_functions.ipynb"
# %run "C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\data_analysis_functions.ipynb"

# %% [markdown]
# #### <font color='darkorange'> Read the data (test runs below 15 seconds)

# %%
file_path = "C:/Users/anasofiaccruz/Desktop/Optogenetics processed data/below15_runs.csv"
below15 = pd.read_csv(file_path)

# %%
below15.head(3)
# Out:
#                session    rat  run_nr  start_timestamp run_type  \
# 0  2019-08-08T12_41_07  NPHR1     6.0       368.579635        T
# 1  2019-08-08T12_41_07  NPHR1    10.0       751.518003        T
# 2  2019-08-08T12_41_07  NPHR1    14.0       954.084992        T
#
#    stim_condition  outcome group  cp_entry_timestamp  cp_exit_timestamp  \
# 0               1      1.0  NPHR          371.569088         372.640947
# 1               3      1.0  NPHR          755.435469         756.431386
# 2               3      0.0  NPHR          957.866982         958.900954
#
#    latency_to_cp_entry  latency_to_cp_exit  time_in_cp
# 0             2.989453            4.061312    1.071859
# 1             3.917466            4.913382    0.995917
# 2             3.781990            4.815962    1.033971

# %% [markdown]
# ### Remove baseline trials

# %%
below15 = below15[(below15['stim_condition']!=-1)]
below15['stim_condition'].unique()
# Out:
# array([1, 3, 0], dtype=int64)

# %% [markdown]
# # <font color='darkorange'> Time spent in choice point distributions

# %% [markdown]
# ### Calculation of time spent in choice point

# %%
below15['time_in_cp'] = below15['latency_to_cp_exit']-below15['latency_to_cp_entry']
# Drop runs with time in cp below zero (only 6 runs, from the same rat and session)
below15 = below15[below15['time_in_cp']>=0]
below15.groupby(['group','stim_condition'])['time_in_cp'].count()
# Out:
# group  stim_condition
# CTRL   0                  954
#        1                  808
#        3                  937
# NPHR   0                 1195
#        1                 1190
#        3                 1161
# Name: time_in_cp, dtype: int64

# %% [markdown]
# ### Histograms, cumulative distributions and qq plots within group

# %%
test_and_none = below15[(below15['stim_condition']==0)| (below15['stim_condition']==3)]
sample_and_none = below15[(below15['stim_condition']==0)| (below15['stim_condition']==1)]

# %%
# %run data_analysis_functions.ipynb
#bins 0.1
g = plot_latency_distributions_within_group(sample_and_none, 'time_in_cp', ['black','royalblue'])
g.set(xlim=[0,5], ylim=[0,0.08])
#sample_and_none.groupby(['group','stim_condition'])['time_in_cp'].describe()

# %%
g = plot_latency_distributions_within_group(test_and_none,'time_in_cp', ['black', 'orangered'])
g.set(xlim=[0,5], ylim=[0,0.08])
test_and_none.groupby(['group','stim_condition'])['time_in_cp'].apply(np.median)
# Out:
# group  stim_condition
# CTRL   0                 0.859162
#        3                 0.827738
# NPHR   0                 0.794125
#        3                 0.827238
# Name: time_in_cp, dtype: float64

# %%
 g = plot_cumulative_distributions_within_group(below15, 'time_in_cp')
# subplot specs
axes = g.axes.flatten()
xticks = range(0,2)
xlim = [0,2]

axes[0].set(title="NpHR-", xlabel='Time (s)', xlim=xlim, xticks=xticks, xticklabels=xticks)
axes[0].axhline(0.5, linestyle='dashed', c='black', linewidth=1.5)
axes[1].set(title="NpHR+", xlabel='Time (s)', xlim=xlim, xticks=xticks, xticklabels=xticks)
axes[1].axhline(0.5, linestyle='dashed', c='black', linewidth=1.5)

# %% [markdown]
# ### Inference testing on latency to choice point distributions within group

# %%
ctrl_none = below15[(below15['stim_condition']==0) & (below15['group']=='CTRL')]
ctrl_sample= below15[(below15['stim_condition']==1) & (below15['group']=='CTRL')]
ctrl_test= below15[(below15['stim_condition']==3) & (below15['group']=='CTRL')]
nphr_none = below15[(below15['stim_condition']==0) & (below15['group']=='NPHR')]
nphr_sample= below15[(below15['stim_condition']==1) & (below15['group']=='NPHR')]
nphr_test= below15[(below15['stim_condition']==3) & (below15['group']=='NPHR')]

# %%
a = [ctrl_none, ctrl_none, nphr_none, nphr_none]
b = [ctrl_sample, ctrl_test, nphr_sample, nphr_test]
#Alpha with bonferroni correction = 0.05/4 = 0.0125
results = inference_testing_mannwhitneyu(a, b, 'time_in_cp')
results
# Out:
#   a_group b_group  a_condition  b_condition  a_outcome  b_outcome         u  \
# 0    CTRL    CTRL          0.0          1.0        1.0        1.0  363731.0
# 1    CTRL    CTRL          0.0          3.0        1.0        1.0  439772.0
# 2    NPHR    NPHR          0.0          1.0        1.0        1.0  701905.0
# 3    NPHR    NPHR          0.0          3.0        1.0        1.0  646496.5
#
#           p
# 0  0.041583
# 1  0.545509
# 2  0.587587
# 3  0.004246

# %% [markdown]
# ### Histograms, cumulative distributions and qq plots within condition

# %%
g = plot_latency_distributions_within_condition(below15,'time_in_cp')
g.set(xlim=[0,5])

# %%
g = plot_cumulative_distributions_within_condition(below15, 'time_in_cp')
g.set(xlabel='Latency(s)', xlim=[0,2], xticks=range(0,3), xticklabels=range(0,3))

# %% [markdown]
# ###  Inference testing on time in cp distributions within conditions

# %%
a = [ctrl_none, ctrl_sample, ctrl_test]
b = [nphr_none, nphr_sample, nphr_test]
results = inference_testing_mannwhitneyu(a,b,'time_in_cp')
# Alpha with bonferroni correction = 0.05 /3 = 0.016
results
# Out:
#   a_group b_group  a_condition  b_condition  a_outcome  b_outcome         u  \
# 0    CTRL    NPHR          0.0          0.0        1.0        1.0  619309.0
# 1    CTRL    NPHR          1.0          1.0        1.0        1.0  545033.0
# 2    CTRL    NPHR          3.0          3.0        1.0        1.0  560574.0
#
#               p
# 0  5.625057e-04
# 1  3.805478e-07
# 2  2.275659e-01

# %% [markdown]
# #### After correcting the alpha, we find a signifcant difference between the CTRL and the NPHR group for the no illumination and the sample illumination.
