# %% [markdown]
# # <font color=dodgerblue> Visual check of individual runs according to session name
# ***
# ### To visually check all the position data classified as an individual run.
# ### It will be necessary to determine which runs are "real" and with are not and, secondly, it will allow the building of a run specs file per session, containing run-relevant information such as stim condition, outcome etc.
# ### The raw timestamped position dataframe (no run specifications) will be saved into the files_path
# ***

# %% [markdown]
# ## <font color=firebrick>Imports
# ***

# %%
import pandas as pd
import numpy as np
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns

from collect_and_organize_position_data_optogenetics import collect_and_organize_position_data

# %% [markdown]
# ## <font color=firebrick> Path
# ***

# %%
files_path = "E:\POSITION DATA\PRE PROCESSED\GERONIMO_CTRL5"

# %% [markdown]
# ## <font color=mediumseagreen> Collect data and save into a .csv file
# ***
#
# #### Collection of a dataframe with the timestamped position data from all sessions.
# #### Interpolates NaN values and zeros in the data and checks for length discrepancies for same session position and timestamp data
# #### Subdivides the position data into runs, labelling them with a run number and the corresponding session

# %%
# Collect a dataframe with position data from all sessions.
data = collect_and_organize_position_data(files_path)
# Out:
#  Opening timestamps:GERONIMO_DNMP10_PRESTIM1_XY_TIMESTAMPS_2020-11-09T12_42_18.csv. Length:105357
#
#  Opening position:GERONIMO_DNMP10_PRESTIM1_CENTROID_POSITION2020-11-09T12_42_18.csv. Length:105357
# 2020-11-09T12_42_18
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP11_PRESTIM2_XY_TIMESTAMPS_2020-11-10T11_26_11.csv. Length:74056
#
#  Opening position:GERONIMO_DNMP11_PRESTIM2_CENTROID_POSITION2020-11-10T11_26_11.csv. Length:74056
# 2020-11-10T11_26_11
# 45   -20
# Name: diff, dtype: int64
# -20
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP12_PRESTIM3_XY_TIMESTAMPS_2020-11-11T09_36_04.csv. Length:172265
#
#  Opening position:GERONIMO_DNMP12_PRESTIM3_CENTROID_POSITION2020-11-11T09_36_04.csv. Length:172265
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# 2020-11-11T09_36_04
# 46   -60
# Name: diff, dtype: int64
# -60
#
#  Opening timestamps:GERONIMO_DNMP13_STIM1_XY_TIMESTAMPS_2020-11-12T13_00_04.csv. Length:89063
#
#  Opening position:GERONIMO_DNMP13_STIM1_CENTROID_POSITION2020-11-12T13_00_04.csv. Length:89063
# 2020-11-12T13_00_04
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP14_STIM2_XY_TIMESTAMPS_2020-11-16T09_48_33.csv. Length:114788
#
#  Opening position:GERONIMO_DNMP14_STIM2_CENTROID_POSITION2020-11-16T09_48_33.csv. Length:114788
# 2020-11-16T09_48_33
# 47   -60
# Name: diff, dtype: int64
# -60
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP15_STIM3_XY_TIMESTAMPS_2020-11-18T09_56_35.csv. Length:98555
#
#  Opening position:GERONIMO_DNMP15_STIM3_CENTROID_POSITION2020-11-18T09_56_35.csv. Length:98555
# 2020-11-18T09_56_35
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP16_STIM4_XY_TIMESTAMPS_2020-11-19T09_00_26.csv. Length:94404
#
#  Opening position:GERONIMO_DNMP16_STIM4_CENTROID_POSITION2020-11-19T09_00_26.csv. Length:94404
# 2020-11-19T09_00_26
# 48   -60
# Name: diff, dtype: int64
# -60
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP17_STIM5_XY_TIMESTAMPS_2020-11-20T08_15_22.csv. Length:91352
#
#  Opening position:GERONIMO_DNMP17_STIM5_CENTROID_POSITION2020-11-20T08_15_22.csv. Length:91352
# 2020-11-20T08_15_22
# 49   -10
# Name: diff, dtype: int64
# -10
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP18_STIM6_XY_TIMESTAMPS_2020-11-24T09_56_24.csv. Length:93565
#
#  Opening position:GERONIMO_DNMP18_STIM6_CENTROID_POSITION2020-11-24T09_56_24.csv. Length:93565
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# 2020-11-24T09_56_24
# 50   -30
# Name: diff, dtype: int64
# -30
#
#  Opening timestamps:GERONIMO_DNMP20_STIM8_XY_TIMESTAMPS_2020-11-26T11_15_50.csv. Length:84759
#
#  Opening position:GERONIMO_DNMP20_STIM8_CENTROID_POSITION2020-11-26T11_15_50.csv. Length:84759
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# 2020-11-26T11_15_50
# 52   -80
# Name: diff, dtype: int64
# -80
#
#  Opening timestamps:GERONIMO_DNMP21_STIM9_XY_TIMESTAMPS_2020-11-27T12_31_07.csv. Length:84943
#
#  Opening position:GERONIMO_DNMP21_STIM9_CENTROID_POSITION2020-11-27T12_31_07.csv. Length:84894
#
#  N points in session 2020-11-27T12_31_07 is different!
#
# 2020-11-27T12_31_07
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP22_STIM10_XY_TIMESTAMPS_2020-11-30T11_19_35.csv. Length:86417
#
#  Opening position:GERONIMO_DNMP22_STIM10_CENTROID_POSITION2020-11-30T11_19_35.csv. Length:86417
# 2020-11-30T11_19_35
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP23_STIM11_XY_TIMESTAMPS_2020-12-01T15_23_42.csv. Length:84685
#
#  Opening position:GERONIMO_DNMP23_STIM11_CENTROID_POSITION2020-12-01T15_23_42.csv. Length:84685
# 2020-12-01T15_23_42
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP24_STIM12_XY_TIMESTAMPS_2020-12-02T11_41_19.csv. Length:112420
#
#  Opening position:GERONIMO_DNMP24_STIM12_CENTROID_POSITION2020-12-02T11_41_19.csv. Length:112420
# 2020-12-02T11_41_19
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP25_STIM13_XY_TIMESTAMPS_2020-12-03T12_54_02.csv. Length:93591
#
#  Opening position:GERONIMO_DNMP25_STIM13_CENTROID_POSITION2020-12-03T12_54_02.csv. Length:93591
# 2020-12-03T12_54_02
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP26_STIM14_XY_TIMESTAMPS_2020-12-04T08_29_50.csv. Length:87307
#
#  Opening position:GERONIMO_DNMP26_STIM14_CENTROID_POSITION2020-12-04T08_29_50.csv. Length:87307
# 2020-12-04T08_29_50
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERONIMO_DNMP27_STIM15_XY_TIMESTAMPS_2020-12-07T11_44_05.csv. Length:98717
#
#  Opening position:GERONIMO_DNMP27_STIM15_CENTROID_POSITION2020-12-07T11_44_05.csv. Length:98717
# 2020-12-07T11_44_05
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:GERÓNIMO_DNMP19_STIM7_XY_TIMESTAMPS_2020-11-25T09_53_37.csv. Length:85367
#
#  Opening position:GERÓNIMO_DNMP19_STIM7_CENTROID_POSITION2020-11-25T09_53_37.csv. Length:85367
# 2020-11-25T09_53_37
# 51   -20
# Name: diff, dtype: int64
# -20
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\Preprocessing\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# Drop timestamps with NaN
data = data.dropna(subset=['timestamp'])

# %% [markdown]
# ## <font color=mediumseagreen> Save the timestamped position DataFrame into a .csv file
# ***

# %%
# Create a folder named "Timestamped_Position" inside the files path
try:
    os.mkdir(os.path.join(files_path, "Timestamped_Position"))
except:
    pass

# %%
# Find rat code in files_path.
match = re.search(r"_(\w+\d+)", files_path)
rat = match.group(1)

path = os.path.join(files_path,"Timestamped_Position", "%s_timestamped_position_df_raw.csv"%rat)
data.to_csv(path, header=True)

# %% [markdown]
# ## <font color=mediumseagreen> Plot session runs to check individual runs
# ***

# %%
data.head(10)
# Out:
#       timestamp         x         y   x_diff  run_nr              session
# 2149  71.045094  38.39906  66.80094  0.00000     1.0  2020-11-09T12_42_18
# 2150  71.078246  38.44096  66.94762  0.04190     1.0  2020-11-09T12_42_18
# 2156  71.276890  38.12428  66.83236 -0.31668     1.0  2020-11-09T12_42_18
# 2157  71.310029  38.03044  66.70000 -0.09384     1.0  2020-11-09T12_42_18
# 2158  71.342771  38.08140  66.75814  0.05096     1.0  2020-11-09T12_42_18
# 2159  71.376486  38.45040  67.06342  0.36900     1.0  2020-11-09T12_42_18
# 2160  71.408973  38.37652  67.24014 -0.07388     1.0  2020-11-09T12_42_18
# 2161  71.441843  38.31578  67.48280 -0.06074     1.0  2020-11-09T12_42_18
# 2162  71.475584  38.59734  67.69800  0.28156     1.0  2020-11-09T12_42_18
# 2163  71.507853  38.54526  67.68702 -0.05208     1.0  2020-11-09T12_42_18

# %%
#Retrieve data from the given session
session ="2020-11-24T09_56_24"
session_data = data[data["session"] == session]

# %%
session_data.head()
# Out:
#    timestamp          x         y  x_diff  run_nr              session
# 0   0.000000  159.53334  3.533334     0.0     1.0  2020-11-24T09_56_24
# 1   0.006310  159.53334  3.533334     0.0     1.0  2020-11-24T09_56_24
# 2   0.017664  159.53334  3.533334     0.0     1.0  2020-11-24T09_56_24
# 3   0.050598  159.53334  3.533334     0.0     1.0  2020-11-24T09_56_24
# 4   0.083661  159.53334  3.533334     0.0     1.0  2020-11-24T09_56_24

# %%
sns.set(style='white', context='talk')
g = sns.relplot(kind='scatter', data=session_data, x='x', y='y', col='run_nr', col_wrap=4)
plt.show()

# %% [markdown]
# # ***
# # <font color=dodgerblue> Creating a run specs file
# ***
#
#
# ### Confirm that all runs are visually consistent with the rat's trajectories in space. Create a run_specs .csv file (for example: 'HEFESTO_RUN_SPECS_DNMP31_STIM10_2020-06-30T14_05_16.csv'), containing a mapping between the run numbers and each run information:
#    #### 1st. column - run_nr;
#    #### 2nd column - run_type ('S', sample or 'T', test);
#    #### 3rd column - stim_condition(0,1,3);
#    #### 4th column - outcome(0 - error, 1 - correct).
#    #### If a run does not exist (is not visually consistent with a rat' trajectory, all other columns should contain 'NaN').
#    #### Column names should not be included in the file. They are added later on!
# ### Save as a .csv file into the directory containing the position and timestamp files, such that the run specifications can be added later on during the analysis.

# %% [markdown]
# #
