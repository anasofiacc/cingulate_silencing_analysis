# %% [markdown]
# # <font color=dodgerblue> Visual check of individual runs according to session name
# ***
# ### To visually check all the position data classified as an individual run.
# ### It will be necessary to determine which runs are "real" and with are not and, secondly, it will allow the building of a run specs file per session, containing run-relevant information such as stim condition, outcome etc.
# ### The raw timestamped position dataframe (no run specifications) will be saved into the files_path
# ***

# %% [markdown]
# ## <font color=firebrick>Imports
# ***

# %%
import pandas as pd
import numpy as np
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns

from collect_and_organize_position_data_optogenetics import collect_and_organize_position_data

# %% [markdown]
# ## <font color=firebrick> Inputs
# ***

# %%
files_path = "E:\POSITION DATA\MANJERICO_NPHR9"
#session ="2021-03-09T10_01_01"

# %% [markdown]
# ## <font color=mediumseagreen> Collect data and save into a .csv file
# ***
#
# #### Collection of a dataframe with the timestamped position data from all sessions.
# #### Interpolates NaN values and zeros in the data and checks for length discrepancies for same session position and timestamp data
# #### Subdivides the position data into runs, labelling them with a run number and the corresponding session

# %%
# Collect a dataframe with position data from all sessions.
data = collect_and_organize_position_data(files_path)
# Out:
#  Opening timestamps:MANJERICO_DNMP10_STIM1_XY_TIMESTAMPS_2020-11-18T13_21_01.csv. Length:94015
#
#  Opening position:MANJERICO_DNMP10_STIM1_CENTROID_POSITION2020-11-18T13_21_01.csv. Length:94015
# 2020-11-18T13_21_01
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP11_STIM2_XY_TIMESTAMPS_2020-11-19T10_04_05.csv. Length:87689
#
#  Opening position:MANJERICO_DNMP11_STIM2_CENTROID_POSITION2020-11-19T10_04_05.csv. Length:87689
# 2020-11-19T10_04_05
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP12_STIM3_XY_TIMESTAMPS_2020-11-20T09_08_57.csv. Length:93441
#
#  Opening position:MANJERICO_DNMP12_STIM3_CENTROID_POSITION2020-11-20T09_08_57.csv. Length:93441
# 2020-11-20T09_08_57
# 53   -20
# Name: diff, dtype: int64
# -20
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP13_STIM4_XY_TIMESTAMPS_2020-11-24T11_09_12.csv. Length:83594
#
#  Opening position:MANJERICO_DNMP13_STIM4_CENTROID_POSITION2020-11-24T11_09_12.csv. Length:83594
# 2020-11-24T11_09_12
# 54   -20
# Name: diff, dtype: int64
# -20
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP14_STIM5_XY_TIMESTAMPS_2020-11-25T13_17_47.csv. Length:85564
#
#  Opening position:MANJERICO_DNMP14_STIM5_CENTROID_POSITION2020-11-25T13_17_47.csv. Length:85564
# 2020-11-25T13_17_47
# 55   -20
# Name: diff, dtype: int64
# -20
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP15_STIM6_XY_TIMESTAMPS_2020-11-26T13_05_35.csv. Length:85342
#
#  Opening position:MANJERICO_DNMP15_STIM6_CENTROID_POSITION2020-11-26T13_05_35.csv. Length:85342
# 2020-11-26T13_05_35
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP16_STIM7_XY_TIMESTAMPS_2020-11-27T16_09_42.csv. Length:83925
#
#  Opening position:MANJERICO_DNMP16_STIM7_CENTROID_POSITION2020-11-27T16_09_42.csv. Length:83925
# 2020-11-27T16_09_42
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP17_STIM8_XY_TIMESTAMPS_2020-11-30T13_13_02.csv. Length:86749
#
#  Opening position:MANJERICO_DNMP17_STIM8_CENTROID_POSITION2020-11-30T13_13_02.csv. Length:86749
# 2020-11-30T13_13_02
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP18_STIM9_XY_TIMESTAMPS_2020-12-01T16_10_51.csv. Length:86499
#
#  Opening position:MANJERICO_DNMP18_STIM9_CENTROID_POSITION2020-12-01T16_10_51.csv. Length:86499
# 2020-12-01T16_10_51
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP19_STIM10_XY_TIMESTAMPS_2020-12-02T16_38_02.csv. Length:82563
#
#  Opening position:MANJERICO_DNMP19_STIM10_CENTROID_POSITION2020-12-02T16_38_02.csv. Length:82563
# 2020-12-02T16_38_02
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP20_STIM11_XY_TIMESTAMPS_2020-12-03T15_29_16.csv. Length:84906
#
#  Opening position:MANJERICO_DNMP20_STIM11_CENTROID_POSITION2020-12-03T15_29_16.csv. Length:84761
#
#  N points in session 2020-12-03T15_29_16 is different!
#
# 2020-12-03T15_29_16
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP21_STIM12_XY_TIMESTAMPS_2020-12-04T12_44_55.csv. Length:84143
#
#  Opening position:MANJERICO_DNMP21_STIM12_CENTROID_POSITION2020-12-04T12_44_55.csv. Length:84143
# 2020-12-04T12_44_55
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP22_STIM13_XY_TIMESTAMPS_2020-12-07T12_44_10.csv. Length:92477
#
#  Opening position:MANJERICO_DNMP22_STIM13_CENTROID_POSITION2020-12-07T12_44_10.csv. Length:92474
#
#  N points in session 2020-12-07T12_44_10 is different!
#
# 2020-12-07T12_44_10
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP23_STIM14_XY_TIMESTAMPS_2020-12-08T14_51_38.csv. Length:85644
#
#  Opening position:MANJERICO_DNMP23_STIM14_CENTROID_POSITION2020-12-08T14_51_38.csv. Length:85644
# 2020-12-08T14_51_38
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP24_STIM15_XY_TIMESTAMPS_2020-12-09T10_21_43.csv. Length:85081
#
#  Opening position:MANJERICO_DNMP24_STIM15_CENTROID_POSITION2020-12-09T10_21_43.csv. Length:85081
# 2020-12-09T10_21_43
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP7_PRESTIM1_XY_TIMESTAMPS_2020-11-12T09_32_34.csv. Length:122960
#
#  Opening position:MANJERICO_DNMP7_PRESTIM1_CENTROID_POSITION2020-11-12T09_32_34.csv. Length:122960
# 2020-11-12T09_32_34
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP8_PRESTIM2_XY_TIMESTAMPS_2020-11-16T11_09_38.csv. Length:125988
#
#  Opening position:MANJERICO_DNMP8_PRESTIM2_CENTROID_POSITION2020-11-16T11_09_38.csv. Length:125988
# 2020-11-16T11_09_38
# 52   -50
# Name: diff, dtype: int64
# -50
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Opening timestamps:MANJERICO_DNMP9_PRESTIM3_XY_TIMESTAMPS_2020-11-17T13_12_46.csv. Length:99409
#
#  Opening position:MANJERICO_DNMP9_PRESTIM3_CENTROID_POSITION2020-11-17T13_12_46.csv. Length:99409
# 2020-11-17T13_12_46
# Series([], Name: diff, dtype: int64)
# -100
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\collect_and_organize_position_data_optogenetics.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# Drop timestamps with NaN
data = data.dropna(subset=['timestamp'])

# %% [markdown]
# ## <font color=mediumseagreen> Save the timestamped position DataFrame into a .csv file
# ***

# %%
# Create a folder named "Timestamped_Position" inside the files path
try:
    os.mkdir(os.path.join(files_path, "Timestamped_Position"))
except:
    pass

# %%
# Find rat code in files_path.
match = re.search(r"_(\w+\d+)", files_path)
rat = match.group(1)

path = os.path.join(files_path,"Timestamped_Position", "%s_timestamped_position_df_raw.csv"%rat)
data.to_csv(path, header=True)

# %% [markdown]
# ## <font color=mediumseagreen> Plot session runs to check individual runs
# ***

# %%
#Retrieve data from the given session
session ="2020-11-26T13_05_35"
session_data = data[data["session"] == session]

# %%
session_data.head()
# Out:
#    timestamp          x         y   x_diff  run_nr              session
# 0   0.000000  116.43676  64.50424  0.00000     1.0  2020-11-26T13_05_35
# 1   0.023027  116.40042  64.08186 -0.03634     1.0  2020-11-26T13_05_35
# 2   0.055603  116.31908  63.85074 -0.08134     1.0  2020-11-26T13_05_35
# 3   0.088896  116.37206  63.87824  0.05298     1.0  2020-11-26T13_05_35
# 4   0.121946  116.49872  63.94444  0.12666     1.0  2020-11-26T13_05_35

# %%
sns.set(style='white', context='talk')
g = sns.relplot(kind='scatter', data=session_data, x='x', y='y', col='run_nr', col_wrap=4)
plt.show()

# %% [markdown]
# # ***
# # <font color=dodgerblue> Creating a run specs file
# ***
#
#
# ### Confirm that all runs are visually consistent with the rat's trajectories in space. Create a run_specs .csv file (for example: 'HEFESTO_RUN_SPECS_DNMP31_STIM10_2020-06-30T14_05_16.csv'), containing a mapping between the run numbers and each run information:
#    #### 1st. column - run_nr;
#    #### 2nd column - run_type ('S', sample or 'T', test);
#    #### 3rd column - stim_condition(0,1,3);
#    #### 4th column - outcome(0 - error, 1 - correct).
#    #### If a run does not exist (is not visually consistent with a rat' trajectory, all other columns should contain 'NaN'.
#    #### Column names should not be included in the file. They are added later on!
# ### Save as a .csv file into the directory containing the position and timestamp files, such that the run specifications can be added later on during the analysis.

# %% [markdown]
# #

# %%
# Open RW1 and RW2 limits .csv files
rw1_rois_path = os.path.join(files_path, "ROIS", "%s_rw1_rois_converted.csv"%rat)
rw2_rois_path = os.path.join(files_path, "ROIS", "%s_rw2_rois_converted.csv"%rat)

rw1_rois = pd.read_csv(rw1_rois_path, header=0, index_col=0)
rw2_rois = pd.read_csv(rw2_rois_path, header=0, index_col=0)

# %%
# Create a rw limit box for detection
for rois in [rw1_rois, rw2_rois]:
    
    rois['ylim1'] = rois['y'] - 25
    rois['ylim2'] = rois['y'] + 25
    rois['xlim1'] = rois['x'] - 5
    rois['xlim2'] = rois['x'] + 5
    
rw1_rois.to_csv(os.path.join(files_path, "ROIS", "%s_rw1_rois_final.csv"%rat))
rw2_rois.to_csv(os.path.join(files_path,"ROIS", "%s_rw2_rois_final.csv"%rat))

# %%
def find_session_match_in_roi_df(roi_df, session):
    
    '''
    Returns ROI limits from roi_df according to the given session.
    '''
    mask = roi_df['session'].str.contains(session[0:15], regex=False)    
    roi_df = roi_df[mask]

    return roi_df

def prune_runs(group, rw1_rois, rw2_rois):
    
    '''
    Returns the run data pruned by removing the position data after the rat is detected past the 4 cm until the RW port
    '''  
    # Get RW1 andS RW2 limits according to session
    session = '2020-11-26T13_05_35'
    run_nr = group['run_nr'].iloc[0]
    
  
    #if group['stim_condition'].iloc[0] == 2 or group['stim_condition'].iloc[0] == 4:
        
    #    group.loc[:,:] = np.nan
    
    #else:
  
    rw1_session = find_session_match_in_roi_df(rw1_rois, session)
    rw2_session = find_session_match_in_roi_df(rw2_rois, session)
   
    # Create a mask to keep only data inside these ROIS
    rw1_mask = ((group['x'] <= rw1_session['xlim2'].iloc[0]) & 
                (group['y'].between(rw1_session['ylim1'].iloc[0], rw1_session['ylim2'].iloc[0])))                                                              
    rw2_mask = ((group['x'] <= rw2_session['xlim2'].iloc[0]) & 
                (group['y'].between(rw2_session['ylim1'].iloc[0], rw2_session['ylim2'].iloc[0])))

    # Apply the mask to the run and collect the first timestamp (1st detected point in either ROIs)
    group_masked = group[((rw2_mask) | (rw1_mask))]

    # Drop data in the run past timestamp
    try:
        timestamp = group_masked['timestamp'].iloc[0]
        group = group[group['timestamp'] <= timestamp]
    except:
        print('removed group: %s, %s'%(session, run_nr))
        group.loc[:,:] = np.nan

    return group
# Out:
#   File "<ipython-input-32-a2d3a781a4bd>", line 27
#     rw1_session = find_session_match_in_roi_df(rw1_rois, session)
#     ^
# IndentationError: unexpected indent

# %%
# Drop backward movements after reward by removing datapoints after the arrival to 3 cm before the reward port
session_data = session_data.groupby(["run_nr"]).apply(prune_runs, rw1_rois, rw2_rois).dropna()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stim_condition'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-0121d9add682> in <module>
#       1 # Drop backward movements after reward by removing datapoints after the arrival to 3 cm before the reward port
# ----> 2 session_data = session_data.groupby(["run_nr"]).apply(prune_runs, rw1_rois, rw2_rois).dropna()
#
# ~\Anaconda3\envs\ds\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     892         with option_context("mode.chained_assignment", None):
#     893             try:
# --> 894                 result = self._python_apply_general(f, self._selected_obj)
#     895             except TypeError:
#     896                 # gh-20949
#
# ~\Anaconda3\envs\ds\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f, data)
#     926             data after applying f
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#     930         return self._wrap_applied_output(
#
# ~\Anaconda3\envs\ds\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     236             # group might be modified
#     237             group_axes = group.axes
# --> 238             res = f(group)
#     239             if not _is_indexed_like(res, group_axes, axis):
#     240                 mutated = True
#
# ~\Anaconda3\envs\ds\lib\site-packages\pandas\core\groupby\groupby.py in f(g)
#     876                 def f(g):
#     877                     with np.errstate(all="ignore"):
# --> 878                         return func(g, *args, **kwargs)
#     879
#     880             elif hasattr(nanops, "nan" + func):
#
# <ipython-input-28-3b50a928d78b> in prune_runs(group, rw1_rois, rw2_rois)
#       9
#      10
# ---> 11     if group['stim_condition'].iloc[0] == 2 or group['stim_condition'].iloc[0] == 4:
#      12
#      13         group.loc[:,:] = np.nan
#
# ~\Anaconda3\envs\ds\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\Anaconda3\envs\ds\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'stim_condition'
