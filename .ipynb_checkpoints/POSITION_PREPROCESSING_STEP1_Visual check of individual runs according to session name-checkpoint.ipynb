# %% [markdown]
# # <font color=dodgerblue> Visual check of individual runs according to session name
# ***
# ### To visually check all the position data classified as an individual run.
# ### It will be necessary to determine which runs are "real" and with are not and, secondly, it will allow the building of a run specs file per session, containing run-relevant information such as stim condition, outcome etc.
# ### The raw timestamped position dataframe (no run specifications) will be saved into the files_path
# ***

# %% [markdown]
# ## <font color=firebrick>Imports
# ***

# %%
import pandas as pd
import numpy as np
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns

from collect_and_organize_position_data_optogenetics import collect_and_organize_position_data

# %% [markdown]
# ## <font color=firebrick> Inputs
# ***

# %%
files_path = "E:\POSITION DATA\APOLLO_CTRL4"
session = "2020-11-17T14_26_24"

# %% [markdown]
# ## <font color=mediumseagreen> Collect data and save into a .csv file
# ***
#
# #### Collection of a dataframe with the timestamped position data from all sessions.
# #### Interpolates NaN values and zeros in the data and checks for length discrepancies for same session position and timestamp data
# #### Subdivides the position data into runs, labelling them with a run number and the corresponding session

# %%
# Collect a dataframe with position data from all sessions.
data = collect_and_organize_position_data(files_path)
# Out:
#  Opening timestamps:APOLLO_DNMP16_PRESTIM1_XY_TIMESTAMPS_2020-11-17T14_26_24.csv. Length:93231
#
#  Opening position:APOLLO_DNMP16_PRESTIM1_CENTROID_POSITION2020-11-17T14_26_24.csv. Length:93231
# 2020-11-17T14_26_24
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP17PRESTIM2_XY_TIMESTAMPS_2020-11-18T14_21_56.csv. Length:89648
#
#  Opening position:APOLLO_DNMP17_PRESTIM2_CENTROID_POSITION2020-11-18T14_21_56.csv. Length:89648
# 2020-11-18T14_21_56
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP18_PRESTIM3_XY_TIMESTAMPS_2020-11-19T14_40_31.csv. Length:86040
#
#  Opening position:APOLLO_DNMP18_PRESTIM3_CENTROID_POSITION2020-11-19T14_40_31.csv. Length:86040
# 2020-11-19T14_40_31
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP19_STIM1_XY_TIMESTAMPS_2020-11-20T15_12_30.csv. Length:85047
#
#  Opening position:APOLLO_DNMP19_STIM1_CENTROID_POSITION2020-11-20T15_12_30.csv. Length:85047
# 2020-11-20T15_12_30
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP20_STIM2_XY_TIMESTAMPS_2020-11-23T11_15_03.csv. Length:90600
#
#  Opening position:APOLLO_DNMP20_STIM2_CENTROID_POSITION2020-11-23T11_15_03.csv. Length:90600
# 2020-11-23T11_15_03
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP21_STIM3_XY_TIMESTAMPS_2020-11-24T14_45_11.csv. Length:93999
#
#  Opening position:APOLLO_DNMP21_STIM3_CENTROID_POSITION2020-11-24T14_45_11.csv. Length:93999
# 2020-11-24T14_45_11
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP22_STIM4_XY_TIMESTAMPS_2020-11-25T15_36_33.csv. Length:92279
#
#  Opening position:APOLLO_DNMP22_STIM4_CENTROID_POSITION2020-11-25T15_36_33.csv. Length:92279
# 2020-11-25T15_36_33
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP23_STIM5_STIM_XY_TIMESTAMPS_2020-11-26T15_11_10.csv. Length:86380
#
#  Opening position:APOLLO_DNMP23_STIM5_CENTROID_POSITION2020-11-26T15_11_10.csv. Length:86380
# 2020-11-26T15_11_10
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP24_STIM6_XY_TIMESTAMPS_2020-11-27T13_49_42.csv. Length:89256
#
#  Opening position:APOLLO_DNMP24_STIM6_CENTROID_POSITION2020-11-27T13_49_42.csv. Length:89256
# 2020-11-27T13_49_42
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP25_STIM7_XY_TIMESTAMPS_2020-11-30T16_31_31.csv. Length:91706
#
#  Opening position:APOLLO_DNMP25_STIM7_CENTROID_POSITION2020-11-30T16_31_31.csv. Length:91706
# 2020-11-30T16_31_31
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP26_STIM8_XY_TIMESTAMPS_2020-12-01T13_05_59.csv. Length:93519
#
#  Opening position:APOLLO_DNMP26_STIM8_CENTROID_POSITION2020-12-01T13_05_59.csv. Length:93519
# 2020-12-01T13_05_59
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP27_STIM9_XY_TIMESTAMPS_2020-12-02T13_04_32.csv. Length:98784
#
#  Opening position:APOLLO_DNMP27_STIM9_CENTROID_POSITION2020-12-02T13_04_32.csv. Length:98784
# 2020-12-02T13_04_32
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP28_STIM10_XY_TIMESTAMPS_2020-12-03T11_46_55.csv. Length:90410
#
#  Opening position:APOLLO_DNMP28_STIM10_CENTROID_POSITION2020-12-03T11_46_55.csv. Length:90410
# 2020-12-03T11_46_55
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP29_STIM11_XY_TIMESTAMPS_2020-12-07T14_28_23.csv. Length:89982
#
#  Opening position:APOLLO_DNMP29_STIM11_CENTROID_POSITION2020-12-07T14_28_23.csv. Length:89982
# 2020-12-07T14_28_23
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP30_STIM12_XY_TIMESTAMPS_2020-12-08T11_34_18.csv. Length:77919
#
#  Opening position:APOLLO_DNMP30_STIM12_CENTROID_POSITION2020-12-08T11_34_18.csv. Length:77919
# 2020-12-08T11_34_18
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP31_STIM13_XY_TIMESTAMPS_2020-12-09T13_18_20.csv. Length:89793
#
#  Opening position:APOLLO_DNMP31_STIM13_CENTROID_POSITION2020-12-09T13_18_20.csv. Length:89793
# 2020-12-09T13_18_20
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP32_STIM14_XY_TIMESTAMPS_2020-12-10T14_59_20.csv. Length:102137
#
#  Opening position:APOLLO_DNMP32_STIM14_CENTROID_POSITION2020-12-10T14_59_20.csv. Length:102137
# 2020-12-10T14_59_20
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number
#  Opening timestamps:APOLLO_DNMP33_STIM15_XY_TIMESTAMPS_2020-12-11T09_55_00.csv. Length:95928
#
#  Opening position:APOLLO_DNMP33_STIM15_CENTROID_POSITION2020-12-11T09_55_00.csv. Length:95928
# 2020-12-11T09_55_00
# Series([], Name: diff, dtype: int64)
# -100
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_diff'] = (df['x'].diff()).fillna(0)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['run_nr'] = np.NaN
# C:\Users\anasofiaccruz\Anaconda3\envs\data_analysis\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# E:\SCRIPTS\opto_bhv_analysis\collect_and_organize_position_data_optogenetics.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[i:j, 'run_nr'] = run_number

# %%
# Drop timestamps with NaN
data = data.dropna(subset=['timestamp'])

# %% [markdown]
# ## <font color=mediumseagreen> Save the timestamped position DataFrame into a .csv file
# ***

# %%
# Create a folder named "Timestamped_Position" inside the files path
try:
    os.mkdir(os.path.join(files_path, "Timestamped_Position"))
except:
    pass

# %%
# Find rat code in files_path.
match = re.search(r"_(\w+\d+)", files_path)
rat = match.group(1)

path = os.path.join(files_path,"Timestamped_Position", "%s_timestamped_position_df_raw.csv"%rat)
data.to_csv(path, header=True)

# %% [markdown]
# ## <font color=mediumseagreen> Plot session runs to check individual runs
# ***

# %%
#Retrieve data from the given session
session_data = data[data["session"] == session]

# %%
sns.set(style='white', context='talk')
g = sns.relplot(kind='scatter', data=session_data, x='x', y='y', col='run_nr', col_wrap=4)
plt.show()

# %% [markdown]
#  ***
# # <font color=dodgerblue> Creating a run specs file
# ***
#
#
# ### Confirm that all runs are visually consistent with the rat's trajectories in space. Create a run_specs .csv file (for example: 'HEFESTO_RUN_SPECS_DNMP31_STIM10_2020-06-30T14_05_16.csv'), containing a mapping between the run numbers and each run information:
#    #### 1st. column - run_nr;
#    #### 2nd column - run_type ('S', sample or 'T', test);
#    #### 3rd column - stim_condition(0,1,3);
#    #### 4th column - outcome(0 - error, 1 - correct).
#    #### If a run does not exist (is not visually consistent with a rat' trajectory, all other columns should contain 'NaN'.
#    #### Column names should not be included in the file. They are added later on!
# ### Save into into the directory containing the position and timestamp files, such that the run specifications can be added later on during the analysis.
