# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import wilcoxon
# %matplotlib inline

# %run "C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\data_prep_functions.ipynb"
# %run "C:\Users\anasofiaccruz\Desktop\cingulate_silencing_repo\data_analysis_functions.ipynb"

# %% [markdown]
# ### <font color='darkorange'> Read the data (test runs below 15 seconds)

# %%
file_path = "C:/Users/anasofiaccruz/Desktop/Optogenetics processed data/below15_runs.csv"
below15 = pd.read_csv(file_path)

# %%
below15.head(3)
# Out:
#                session    rat  run_nr  start_timestamp run_type  \
# 0  2019-08-08T12_41_07  NPHR1     6.0       368.579635        T
# 1  2019-08-08T12_41_07  NPHR1    10.0       751.518003        T
# 2  2019-08-08T12_41_07  NPHR1    14.0       954.084992        T
#
#    stim_condition  outcome group  cp_entry_timestamp  cp_exit_timestamp  \
# 0               1      1.0  NPHR          371.569088         372.640947
# 1               3      1.0  NPHR          755.435469         756.431386
# 2               3      0.0  NPHR          957.866982         958.900954
#
#    latency_to_cp_entry  latency_to_cp_exit  time_in_cp
# 0             2.989453            4.061312    1.071859
# 1             3.917466            4.913382    0.995917
# 2             3.781990            4.815962    1.033971

# %% [markdown]
# #### <font color='darkorange'>Remove baseline trials

# %%
below15 = below15[(below15['stim_condition']!=-1)]
below15['stim_condition'].unique()
# Out:
# array([1, 3, 0], dtype=int64)

# %%
counts=below15.groupby(['group','stim_condition']).count()['session']
counts
# Out:
# group  stim_condition
# CTRL   0                  954
#        1                  808
#        3                  937
# NPHR   0                 1196
#        1                 1192
#        3                 1164
# Name: session, dtype: int64

# %% [markdown]
# #### <font color='darkorange'> Latency histograms

# %%
#test_and_none = below15[(below15['stim_condition']==0)| (below15['stim_condition']==3)]
#sample_and_none = below15[(below15['stim_condition']==0)| (below15['stim_condition']==1)]

# %%
#g = plot_latency_distributions_within_group(test_and_none,
#                                            'hist',
#                                            'latency_to_cp_entry',
#                                            ['black', 'orangered'])
a = plot_latency_distributions_within_group(below15,
                                            'kde',
                                            'latency_to_cp_entry',
                                            ['black', 'royalblue','orangered'])

# %% [markdown]
# #### <font color='darkorange'> Cumulative distributions of latencies

# %%
g = plot_cumulative_distributions_within_group(below15, 'latency_to_cp_entry')
# subplot specs
axes = g.axes.flatten()
axes[0].set(title="NpHR-", xlabel='Latency(s)', xticks=range(0,20,5), xticklabels=range(0,20,5))
axes[0].axhline(0.5, 0, 15, linestyle='dashed', c='black', linewidth=1.5)
axes[1].set(title="NpHR+", xlabel='Latency(s)', xticks=range(0,20,5), xticklabels=range(0,20,5))
axes[1].axhline(0.5, 0, 15, linestyle='dashed', c='black', linewidth=1.5)

# %% [markdown]
# #### <font color='darkorange'> QQ plots

# %%
ctrl_none = below15[(below15['stim_condition']==0) & (below15['group']=='CTRL')]
ctrl_sample= below15[(below15['stim_condition']==1) & (below15['group']=='CTRL')]
ctrl_test= below15[(below15['stim_condition']==3) & (below15['group']=='CTRL')]
nphr_none = below15[(below15['stim_condition']==0) & (below15['group']=='NPHR')]
nphr_sample= below15[(below15['stim_condition']==1) & (below15['group']=='NPHR')]
nphr_test= below15[(below15['stim_condition']==3) & (below15['group']=='NPHR')]

# %%
ctrl_none_percentiles = np.percentile(
    ctrl_none['latency_to_cp_entry'], range(0,101,1))
ctrl_sample_percentiles = np.percentile(
    ctrl_sample['latency_to_cp_entry'], range(0,101,1))
ctrl_test_percentiles = np.percentile(
    ctrl_test['latency_to_cp_entry'], range(0,101,1))
nphr_none_percentiles = np.percentile(
    nphr_none['latency_to_cp_entry'], range(0,101,1))
nphr_sample_percentiles = np.percentile(
    nphr_sample['latency_to_cp_entry'], range(0,101,1))
nphr_test_percentiles = np.percentile(
    nphr_test['latency_to_cp_entry'], range(0,101,1))

# %%
g = qqplot_within_group(
    ctrl_none_percentiles, 
    ctrl_sample_percentiles,
    ctrl_test_percentiles,
    ['royalblue','orangered']
)
plt.plot(range(1,15,1), range(1,15,1), linestyle='dotted', c='black')

# %%
g = qqplot_within_group(
    nphr_none_percentiles, 
    nphr_sample_percentiles,
    nphr_test_percentiles, 
    ['royalblue', 'orangered']
)
plt.plot(range(1,15,1), range(1,15,1), linestyle='dotted', c='black')

# %% [markdown]
# ### Inference testing on latency to choice point distributions within group

# %%
results = inference_testing_kruskal_within_group(below15,'latency_to_cp_entry')
results
# Out:
#   group          u         p
# 0  CTRL  19.564234  0.000056
# 1  NPHR   9.851342  0.007258

# %%
# Subdivide the data for multiple comparisons suing mannwhitneyu
nphr_no = below15[(below15['group']=='NPHR') & (below15['stim_condition']==0)]
nphr_sample = below15[(below15['group']=='NPHR') & (below15['stim_condition']==1)]
nphr_test = below15[(below15['group']=='NPHR') & (below15['stim_condition']==3)]

posthoc = inference_testing_mannwhitneyu([nphr_no, nphr_no], [nphr_sample, nphr_test],
                                         'latency_to_cp_entry')

#--- p value acceptance limit with Bonferroni correction: p-value_corr=0.025 ---#
posthoc
# Out:
#   a_group b_group  a_condition  b_condition  a_outcome  b_outcome         u  \
# 0    NPHR    NPHR          0.0          1.0        1.0        1.0  706740.0
# 1    NPHR    NPHR          0.0          3.0        1.0        1.0  647980.0
#
#           p
# 0  0.718377
# 1  0.003663

# %%
# Subdivide the data for multiple comparisons suing mannwhitneyu
ctrl_no = below15[(below15['group']=='CTRL') & (below15['stim_condition']==0)]
ctrl_sample = below15[(below15['group']=='CTRL') & (below15['stim_condition']==1)]
ctrl_test = below15[(below15['group']=='CTRL') & (below15['stim_condition']==3)]

posthoc = inference_testing_mannwhitneyu([ctrl_no, ctrl_no], [ctrl_sample, ctrl_test],
                                         'latency_to_cp_entry')

#--- p value acceptance limit with Bonferroni correction: p-value_corr=0.025 ---#
posthoc
# Out:
#   a_group b_group  a_condition  b_condition  a_outcome  b_outcome         u  \
# 0    CTRL    CTRL          0.0          1.0        1.0        1.0  377602.0
# 1    CTRL    CTRL          0.0          3.0        1.0        1.0  397301.5
#
#           p
# 0  0.462811
# 1  0.000029

# %% [markdown]
# ## <font color='darkorange'> Within condition comparisons

# %% [markdown]
# #### <font color='darkorange'> Latency histograms

# %%
a = plot_latency_distributions_within_condition(below15,'kde','latency_to_cp_entry')
g = plot_cumulative_distributions_within_condition(below15, 'latency_to_cp_entry')
g.set(xlabel='Latency(s)', xticks=range(0,20,5), xticklabels=range(0,20,5))

# %% [markdown]
# ###  Inference testing on latency to choice point distributions within conditions

# %%
a = [ctrl_none, ctrl_sample, ctrl_test]
b = [nphr_none, nphr_sample, nphr_test]
results = inference_testing_mannwhitneyu(a,b, 'latency_to_cp_entry')

# %%
results
# Out:
#   a_group b_group  a_condition  b_condition  a_outcome  b_outcome         u  \
# 0    CTRL    NPHR          0.0          0.0        1.0        1.0  623490.0
# 1    CTRL    NPHR          1.0          1.0        1.0        1.0  531484.0
# 2    CTRL    NPHR          3.0          3.0        1.0        1.0  616751.5
#
#               p
# 0  2.106958e-04
# 1  8.190632e-05
# 2  2.380156e-07

# %%
results = inference_testing_kruskal_within_group(below15,'latency_to_cp_entry')
results
